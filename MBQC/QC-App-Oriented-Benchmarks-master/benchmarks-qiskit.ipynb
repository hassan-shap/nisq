# %% [markdown]
# ### QED-C Prototype Benchmarks - Qiskit Version
# The notebook contains a suite of prototype application benchmarks for the IBM Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one prototype benchmark program.

# %%
import sys,os
sys.path.insert(1, "../")
from MBQC_basic_functions import*

min_qubits=2
max_qubits=10
max_circuits=3
num_shots=1000

backend_id="qasm_simulator"
hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = None

# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('YOUR_API_TOKEN_HERE')

# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"
# group="YOUR_GROUP_NAME"
# project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify the backend using a known "backend_id"
# # Use 'sabre' layout for IBM backends
# exec_options = { "optimization_level":3, "layout_method":'sabre', "routing_method":'sabre' }
# backend_id="ibmq_belem"

# # *** Here's an example of using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # *** Use these lines when running on hardware backend, to limit use of resources
# min_qubits=2
# max_qubits=5
# max_circuits=1
# num_shots=100

# %%
# Custom optimization options can be specified in this cell (below is an example)
# # Add Qiskit pass manager as a custom 'transformer' method
# import _common.transformers.qiskit_passmgr as qiskit_passmgr
# exec_options = { "optimization_level":3, "layout_method":'sabre', "routing_method":'sabre', "transformer": qiskit_passmgr.do_transform }

# # Example of TrueQ Randomized Compilation
# import _common.transformers.trueq_rc as trueq_rc
# exec_options = { "optimization_level":3, "layout_method":'sabre', "routing_method":'sabre', "transformer": trueq_rc.local_rc } 
# # Define a custom noise model to be used during execution
#import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
#exec_options = { "noise_model": noise_model}#custom_qiskit_noise_model.my_noise_model() }
#

# %% [markdown]
# ### Deutsch-Jozsa

# %%
import sys
sys.path.insert(1, "deutsch-jozsa/qiskit")
import dj_benchmark
dj_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Deutsch-Jozsa Benchmark Program - Qiskit
# ... execution starting at Jul 11, 2022 14:51:54 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [2] circuits with num_qubits = 4
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 7, 0.083
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 7, 0.071, 1.0
# Average Creation Time for the 3 qubit group = 0.012 secs
# Average Elapsed Time for the 3 qubit group = 0.092 secs
# Average Execution Time for the 3 qubit group = 0.014 secs
# Average Fidelity for the 3 qubit group = 0.993
# Average Hellinger Fidelity for the 3 qubit group = 0.994
#
# ************
# Executing [2] circuits with num_qubits = 5
# ************
# Executing [2] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 8, 0.088
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 8, 0.071, 1.5
# Average Creation Time for the 4 qubit group = 0.001 secs
# Average Elapsed Time for the 4 qubit group = 0.123 secs
# Average Execution Time for the 4 qubit group = 0.004 secs
# Average Fidelity for the 4 qubit group = 0.993
# Average Hellinger Fidelity for the 4 qubit group = 0.994
#
# ************
# Executing [2] circuits with num_qubits = 7
# ************
# Executing [2] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 8, 0.1
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 8, 0.077, 2.0
# Average Creation Time for the 5 qubit group = 0.001 secs
# Average Elapsed Time for the 5 qubit group = 0.15 secs
# Average Execution Time for the 5 qubit group = 0.004 secs
# Average Fidelity for the 5 qubit group = 0.984
# Average Hellinger Fidelity for the 5 qubit group = 0.985
#
# ************
# Executing [2] circuits with num_qubits = 9
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 8, 0.1
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 8, 0.076, 2.5
# Average Creation Time for the 6 qubit group = 0.0 secs
# Average Elapsed Time for the 6 qubit group = 0.609 secs
# Average Execution Time for the 6 qubit group = 0.004 secs
# Average Fidelity for the 6 qubit group = 0.979
# Average Hellinger Fidelity for the 6 qubit group = 0.98
#
# ************
# Executing [2] circuits with num_qubits = 10
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 10, 0.107
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 10, 0.079, 3.0
# Average Creation Time for the 7 qubit group = 0.0 secs
# Average Elapsed Time for the 7 qubit group = 0.948 secs
# Average Execution Time for the 7 qubit group = 0.008 secs
# Average Fidelity for the 7 qubit group = 0.978
# Average Hellinger Fidelity for the 7 qubit group = 0.978
#
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 10, 0.106
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 10, 0.078, 3.5
# Average Creation Time for the 8 qubit group = 0.001 secs
# Average Elapsed Time for the 8 qubit group = 1.032 secs
# Average Execution Time for the 8 qubit group = 0.023 secs
# Average Fidelity for the 8 qubit group = 0.975
# Average Hellinger Fidelity for the 8 qubit group = 0.976
#
# ************
# Average Depth, ξ (xi) for the 9 qubit group = 10, 0.111
# Average Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 10, 0.08, 4.0
# Average Creation Time for the 9 qubit group = 0.001 secs
# Average Elapsed Time for the 9 qubit group = 1.53 secs
# Average Execution Time for the 9 qubit group = 0.046 secs
# Average Fidelity for the 9 qubit group = 0.975
# Average Hellinger Fidelity for the 9 qubit group = 0.975
#
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 11, 0.11
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 11, 0.079, 4.5
# Average Creation Time for the 10 qubit group = 0.001 secs
# Average Elapsed Time for the 10 qubit group = 1.636 secs
# Average Execution Time for the 10 qubit group = 0.305 secs
# Average Fidelity for the 10 qubit group = 0.964
# Average Hellinger Fidelity for the 10 qubit group = 0.965
#
# ... execution complete at Jul 11, 2022 14:51:57 UTC in 3.261 secs
#
# Sample Circuit:
#          ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q8830_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├────────────
#          ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q8830_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├─────────
#          ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q8830_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├──────
#          ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q8830_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├───
#          ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q8830_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├
#          ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║ └╥┘
# q8830_5: ┤ X ├┤ H ├─░─┤5    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫─
#          └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║
#  c178: 5/═════════════════════════════════════╩══╩══╩══╩══╩═
#                                               0  1  2  3  4
#
# Constant Oracle 'Uf' =
#
# q_0:
#
# q_1:
#
# q_2:
#
# q_3:
#
# q_4:
#
# q_5:
#
#
# Balanced Oracle 'Uf' =
#      ┌───┐ ░                           ░ ┌───┐
# q_0: ┤ X ├─░───■───────────────────────░─┤ X ├
#      └───┘ ░   │                       ░ └───┘
# q_1: ──────░───┼────■──────────────────░──────
#      ┌───┐ ░   │    │                  ░ ┌───┐
# q_2: ┤ X ├─░───┼────┼────■─────────────░─┤ X ├
#      └───┘ ░   │    │    │             ░ └───┘
# q_3: ──────░───┼────┼────┼────■────────░──────
#      ┌───┐ ░   │    │    │    │        ░ ┌───┐
# q_4: ┤ X ├─░───┼────┼────┼────┼────■───░─┤ X ├
#      └───┘ ░ ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐ ░ └───┘
# q_5: ──────░─┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├─░──────
#            ░ └───┘└───┘└───┘└───┘└───┘ ░

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani Benchmark Program - Qiskit
# ... execution starting at Jul 10, 2022 22:46:14 UTC
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 6, 0.141
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 6, 0.116, 1.333
# Average Creation Time for the 3 qubit group = 0.0 secs
# Average Elapsed Time for the 3 qubit group = 0.078 secs
# Average Execution Time for the 3 qubit group = 0.003 secs
# Average Fidelity for the 3 qubit group = 0.988
# Average Hellinger Fidelity for the 3 qubit group = 0.991
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 6, 0.061
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 6, 0.044, 0.667
# Average Creation Time for the 4 qubit group = 0.0 secs
# Average Elapsed Time for the 4 qubit group = 0.463 secs
# Average Execution Time for the 4 qubit group = 0.003 secs
# Average Fidelity for the 4 qubit group = 0.993
# Average Hellinger Fidelity for the 4 qubit group = 0.994
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 7, 0.121
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 7, 0.084, 1.667
# Average Creation Time for the 5 qubit group = 0.0 secs
# Average Elapsed Time for the 5 qubit group = 0.962 secs
# Average Execution Time for the 5 qubit group = 0.004 secs
# Average Fidelity for the 5 qubit group = 0.986
# Average Hellinger Fidelity for the 5 qubit group = 0.987
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 8, 0.175
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 8, 0.119, 3.0
# Average Creation Time for the 6 qubit group = 0.001 secs
# Average Elapsed Time for the 6 qubit group = 1.068 secs
# Average Execution Time for the 6 qubit group = 0.005 secs
# Average Fidelity for the 6 qubit group = 0.985
# Average Hellinger Fidelity for the 6 qubit group = 0.985
#
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 9, 0.183
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 9, 0.122, 3.667
# Average Creation Time for the 7 qubit group = 0.001 secs
# Average Elapsed Time for the 7 qubit group = 1.011 secs
# Average Execution Time for the 7 qubit group = 0.011 secs
# Average Fidelity for the 7 qubit group = 0.977
# Average Hellinger Fidelity for the 7 qubit group = 0.977
#
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 8, 0.153
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 8, 0.099, 3.333
# Average Creation Time for the 8 qubit group = 0.001 secs
# Average Elapsed Time for the 8 qubit group = 1.07 secs
# Average Execution Time for the 8 qubit group = 0.022 secs
# Average Fidelity for the 8 qubit group = 0.976
# Average Hellinger Fidelity for the 8 qubit group = 0.977
#
# ... execution complete at Jul 10, 2022 22:46:18 UTC in 3.347 secs
#
# Sample Circuit:
#         ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q724_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├────────────
#         ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q724_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├─────────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q724_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├──────
#         ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q724_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├───
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q724_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├
#         ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║ └╥┘
# q724_5: ┤ X ├┤ H ├─░─┤5    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫─
#         └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║
#  c23: 5/═════════════════════════════════════╩══╩══╩══╩══╩═
#                                              0  1  2  3  4
#
# Quantum Oracle 'Uf' =
#
# q725_0: ──────────
#
# q725_1: ──────────
#
# q725_2: ──■───────
#           │
# q725_3: ──┼────■──
#           │    │
# q725_4: ──┼────┼──
#         ┌─┴─┐┌─┴─┐
# q725_5: ┤ X ├┤ X ├
#         └───┘└───┘

# %% [markdown]
# ### Bernstein-Vazirani - Method 2

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani Benchmark Program - Qiskit
# ... execution starting at Jul 10, 2022 22:46:19 UTC
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 9, 0.114
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 10, 0.093, 1.0
# Average Creation Time for the 3 qubit group = 0.0 secs
# Average Elapsed Time for the 3 qubit group = 0.291 secs
# Average Execution Time for the 3 qubit group = 0.061 secs
# Average Fidelity for the 3 qubit group = 0.992
# Average Hellinger Fidelity for the 3 qubit group = 0.994
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 12, 0.121
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 14, 0.095, 1.333
# Average Creation Time for the 4 qubit group = 0.0 secs
# Average Elapsed Time for the 4 qubit group = 0.75 secs
# Average Execution Time for the 4 qubit group = 0.066 secs
# Average Fidelity for the 4 qubit group = 0.991
# Average Hellinger Fidelity for the 4 qubit group = 0.992
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 18, 0.185
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 22, 0.142, 2.667
# Average Creation Time for the 5 qubit group = 0.0 secs
# Average Elapsed Time for the 5 qubit group = 0.991 secs
# Average Execution Time for the 5 qubit group = 0.128 secs
# Average Fidelity for the 5 qubit group = 0.982
# Average Hellinger Fidelity for the 5 qubit group = 0.983
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 17, 0.114
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 19, 0.089, 1.667
# Average Creation Time for the 6 qubit group = 0.0 secs
# Average Elapsed Time for the 6 qubit group = 1.024 secs
# Average Execution Time for the 6 qubit group = 0.047 secs
# Average Fidelity for the 6 qubit group = 0.99
# Average Hellinger Fidelity for the 6 qubit group = 0.99
#
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 20, 0.127
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 23, 0.105, 2.0
# Average Creation Time for the 7 qubit group = 0.0 secs
# Average Elapsed Time for the 7 qubit group = 1.014 secs
# Average Execution Time for the 7 qubit group = 0.067 secs
# Average Fidelity for the 7 qubit group = 0.99
# Average Hellinger Fidelity for the 7 qubit group = 0.99
#
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 27, 0.183
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 33, 0.139, 3.667
# Average Creation Time for the 8 qubit group = 0.0 secs
# Average Elapsed Time for the 8 qubit group = 1.087 secs
# Average Execution Time for the 8 qubit group = 0.183 secs
# Average Fidelity for the 8 qubit group = 0.978
# Average Hellinger Fidelity for the 8 qubit group = 0.978
#
# ... execution complete at Jul 10, 2022 22:46:22 UTC in 3.773 secs
#
# Sample Circuit:
#                     ░ ┌─┐     ┌─┐     ┌───┐     ┌───┐┌─┐     ┌───┐     ┌───┐┌─┐»
# q1363_0: ───────────░─┤M├─|0>─┤M├─|0>─┤ H ├──■──┤ H ├┤M├─|0>─┤ H ├──■──┤ H ├┤M├»
#          ┌───┐┌───┐ ░ └╥┘     └╥┘     └───┘┌─┴─┐└───┘└╥┘     └───┘┌─┴─┐└───┘└╥┘»
# q1363_1: ┤ X ├┤ H ├─░──╫───────╫───────────┤ X ├──────╫───────────┤ X ├──────╫─»
#          └───┘└───┘ ░  ║       ║           └───┘      ║           └───┘      ║ »
#   c41: 5/══════════════╩═══════╩══════════════════════╩══════════════════════╩═»
#                        0       1                      2                      3 »
# «              ┌─┐
# «q1363_0: ─|0>─┤M├─|0>─
# «              └╥┘
# «q1363_1: ──────╫──────
# «               ║
# «  c41: 5/══════╩══════
# «               4

# %% [markdown]
# ### Hidden Shift

# %%
import sys
sys.path.insert(1, "hidden-shift/qiskit")
import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hidden Shift Benchmark Program - Qiskit
# ... execution starting at Jul 11, 2022 14:52:22 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 2 qubit group = 7, 0.206
# Average Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 16, 0.094, 2.0
# Average Creation Time for the 2 qubit group = 0.001 secs
# Average Elapsed Time for the 2 qubit group = 0.125 secs
# Average Execution Time for the 2 qubit group = 0.004 secs
# Average Fidelity for the 2 qubit group = 0.98
# Average Hellinger Fidelity for the 2 qubit group = 0.985
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 8, 0.207
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 17, 0.09, 4.0
# Average Creation Time for the 4 qubit group = 0.001 secs
# Average Elapsed Time for the 4 qubit group = 0.569 secs
# Average Execution Time for the 4 qubit group = 0.018 secs
# Average Fidelity for the 4 qubit group = 0.964
# Average Hellinger Fidelity for the 4 qubit group = 0.966
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 8, 0.188
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 16, 0.093, 6.0
# Average Creation Time for the 6 qubit group = 0.001 secs
# Average Elapsed Time for the 6 qubit group = 1.075 secs
# Average Execution Time for the 6 qubit group = 0.009 secs
# Average Fidelity for the 6 qubit group = 0.949
# Average Hellinger Fidelity for the 6 qubit group = 0.95
#
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 8, 0.205
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 16, 0.094, 8.0
# Average Creation Time for the 8 qubit group = 0.001 secs
# Average Elapsed Time for the 8 qubit group = 1.259 secs
# Average Execution Time for the 8 qubit group = 0.053 secs
# Average Fidelity for the 8 qubit group = 0.944
# Average Hellinger Fidelity for the 8 qubit group = 0.944
#
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 8, 0.193
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 17, 0.09, 10.0
# Average Creation Time for the 10 qubit group = 0.001 secs
# Average Elapsed Time for the 10 qubit group = 1.318 secs
# Average Execution Time for the 10 qubit group = 0.28 secs
# Average Fidelity for the 10 qubit group = 0.923
# Average Hellinger Fidelity for the 10 qubit group = 0.923
#
# ... execution complete at Jul 11, 2022 14:52:25 UTC in 3.237 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─┐
# q9428_0: ┤ H ├─░─┤0    ├─░─┤ H ├─░─┤0    ├─░─┤ H ├─░─┤M├───────────────
#          ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░ └╥┘┌─┐
# q9428_1: ┤ H ├─░─┤1    ├─░─┤ H ├─░─┤1    ├─░─┤ H ├─░──╫─┤M├────────────
#          ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║ └╥┘┌─┐
# q9428_2: ┤ H ├─░─┤2    ├─░─┤ H ├─░─┤2    ├─░─┤ H ├─░──╫──╫─┤M├─────────
#          ├───┤ ░ │  Uf │ ░ ├───┤ ░ │  Ug │ ░ ├───┤ ░  ║  ║ └╥┘┌─┐
# q9428_3: ┤ H ├─░─┤3    ├─░─┤ H ├─░─┤3    ├─░─┤ H ├─░──╫──╫──╫─┤M├──────
#          ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║ └╥┘┌─┐
# q9428_4: ┤ H ├─░─┤4    ├─░─┤ H ├─░─┤4    ├─░─┤ H ├─░──╫──╫──╫──╫─┤M├───
#          ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║  ║ └╥┘┌─┐
# q9428_5: ┤ H ├─░─┤5    ├─░─┤ H ├─░─┤5    ├─░─┤ H ├─░──╫──╫──╫──╫──╫─┤M├
#          └───┘ ░ └─────┘ ░ └───┘ ░ └─────┘ ░ └───┘ ░  ║  ║  ║  ║  ║ └╥┘
#  c195: 6/═════════════════════════════════════════════╩══╩══╩══╩══╩══╩═
#                                                       0  1  2  3  4  5
#
# Quantum Oracle 'Uf' =
#
# q9429_0: ──────■──────
#          ┌───┐ │ ┌───┐
# q9429_1: ┤ X ├─■─┤ X ├
#          ├───┤   ├───┤
# q9429_2: ┤ X ├─■─┤ X ├
#          ├───┤ │ ├───┤
# q9429_3: ┤ X ├─■─┤ X ├
#          ├───┤   ├───┤
# q9429_4: ┤ X ├─■─┤ X ├
#          └───┘ │ └───┘
# q9429_5: ──────■──────
#
#
# Quantum Oracle 'Ug' =
#
# q9430_0: ─■─
#           │
# q9430_1: ─■─
#
# q9430_2: ─■─
#           │
# q9430_3: ─■─
#
# q9430_4: ─■─
#           │
# q9430_5: ─■─

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform Benchmark Program - Qiskit
# ... using circuit method 1
# ... execution starting at Jul 11, 2022 14:52:43 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ... number of gates, depth = 11, 8
# ************
# Executing [3] circuits with num_qubits = 3
# ... number of gates, depth = 19, 14
# ************
# Executing [3] circuits with num_qubits = 4
# ... number of gates, depth = 29, 22
# ************
# Average Depth, ξ (xi) for the 2 qubit group = 9, 0.215
# Average Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 18, 0.207, 4.0
# Average Creation Time for the 2 qubit group = 0.002 secs
# Average Elapsed Time for the 2 qubit group = 0.122 secs
# Average Execution Time for the 2 qubit group = 0.004 secs
# Average Fidelity for the 2 qubit group = 0.976
# Average Hellinger Fidelity for the 2 qubit group = 0.982
#
# ************
# Executing [3] circuits with num_qubits = 5
# ... number of gates, depth = 42, 32
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 15, 0.368
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 35, 0.298, 12.0
# Average Creation Time for the 3 qubit group = 0.001 secs
# Average Elapsed Time for the 3 qubit group = 0.551 secs
# Average Execution Time for the 3 qubit group = 0.004 secs
# Average Fidelity for the 3 qubit group = 0.946
# Average Hellinger Fidelity for the 3 qubit group = 0.953
#
# ************
# Executing [3] circuits with num_qubits = 6
# ... number of gates, depth = 58, 44
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 23, 0.474
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 58, 0.346, 24.0
# Average Creation Time for the 4 qubit group = 0.001 secs
# Average Elapsed Time for the 4 qubit group = 1.103 secs
# Average Execution Time for the 4 qubit group = 0.007 secs
# Average Fidelity for the 4 qubit group = 0.893
# Average Hellinger Fidelity for the 4 qubit group = 0.9
#
# ************
# Executing [3] circuits with num_qubits = 7
# ... number of gates, depth = 74, 58
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 33, 0.531
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 87, 0.372, 40.0
# Average Creation Time for the 5 qubit group = 0.001 secs
# Average Elapsed Time for the 5 qubit group = 1.316 secs
# Average Execution Time for the 5 qubit group = 0.011 secs
# Average Fidelity for the 5 qubit group = 0.859
# Average Hellinger Fidelity for the 5 qubit group = 0.863
#
# ************
# Executing [3] circuits with num_qubits = 8
# ... number of gates, depth = 92, 74
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 45, 0.577
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 122, 0.39, 60.0
# Average Creation Time for the 6 qubit group = 0.002 secs
# Average Elapsed Time for the 6 qubit group = 1.52 secs
# Average Execution Time for the 6 qubit group = 0.017 secs
# Average Fidelity for the 6 qubit group = 0.788
# Average Hellinger Fidelity for the 6 qubit group = 0.791
#
# ************
# Executing [3] circuits with num_qubits = 9
# ... number of gates, depth = 111, 92
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 59, 0.64
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 163, 0.408, 84.0
# Average Creation Time for the 7 qubit group = 0.002 secs
# Average Elapsed Time for the 7 qubit group = 1.923 secs
# Average Execution Time for the 7 qubit group = 0.074 secs
# Average Fidelity for the 7 qubit group = 0.721
# Average Hellinger Fidelity for the 7 qubit group = 0.723
#
# ************
# Executing [3] circuits with num_qubits = 10
# ... number of gates, depth = 134, 112
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 75, 0.664
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 210, 0.417, 112.0
# Average Creation Time for the 8 qubit group = 0.002 secs
# Average Elapsed Time for the 8 qubit group = 3.068 secs
# Average Execution Time for the 8 qubit group = 0.199 secs
# Average Fidelity for the 8 qubit group = 0.651
# Average Hellinger Fidelity for the 8 qubit group = 0.653
#
# ************
# Average Depth, ξ (xi) for the 9 qubit group = 93, 0.701
# Average Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 263, 0.428, 144.0
# Average Creation Time for the 9 qubit group = 0.003 secs
# Average Elapsed Time for the 9 qubit group = 2.941 secs
# Average Execution Time for the 9 qubit group = 0.669 secs
# Average Fidelity for the 9 qubit group = 0.59
# Average Hellinger Fidelity for the 9 qubit group = 0.59
#
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 113, 0.718
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 322, 0.433, 180.0
# Average Creation Time for the 10 qubit group = 0.004 secs
# Average Elapsed Time for the 10 qubit group = 1.649 secs
# Average Execution Time for the 10 qubit group = 0.393 secs
# Average Fidelity for the 10 qubit group = 0.51
# Average Hellinger Fidelity for the 10 qubit group = 0.511
#
# ... execution complete at Jul 11, 2022 14:52:52 UTC in 9.161 secs
#
# Sample Circuit:
#                 ░ ┌──────┐ ░  ┌───────┐   ░ ┌──────────┐ ░ ┌─┐
# q10099_0: ──────░─┤0     ├─░──┤ Rz(π) ├───░─┤0         ├─░─┤M├────────────
#           ┌───┐ ░ │      │ ░ ┌┴───────┴┐  ░ │          │ ░ └╥┘┌─┐
# q10099_1: ┤ X ├─░─┤1     ├─░─┤ Rz(π/2) ├──░─┤1         ├─░──╫─┤M├─────────
#           └───┘ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║ └╥┘┌─┐
# q10099_2: ──────░─┤2 qft ├─░─┤ Rz(π/4) ├──░─┤2 inv_qft ├─░──╫──╫─┤M├──────
#           ┌───┐ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║  ║ └╥┘┌─┐
# q10099_3: ┤ X ├─░─┤3     ├─░─┤ Rz(π/8) ├──░─┤3         ├─░──╫──╫──╫─┤M├───
#           └───┘ ░ │      │ ░ ├─────────┴┐ ░ │          │ ░  ║  ║  ║ └╥┘┌─┐
# q10099_4: ──────░─┤4     ├─░─┤ Rz(π/16) ├─░─┤4         ├─░──╫──╫──╫──╫─┤M├
#                 ░ └──────┘ ░ └──────────┘ ░ └──────────┘ ░  ║  ║  ║  ║ └╥┘
#   c213: 5/══════════════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                             0  1  2  3  4
#
# QFT Circuit =
#                 ░                  ░                             ░            »
# q10100_0: ──────░──────────────────░─────────────────────────────░────────────»
#                 ░                  ░                             ░            »
# q10100_1: ──────░──────────────────░─────────────────────────────░──────■─────»
#                 ░                  ░                       ┌───┐ ░      │     »
# q10100_2: ──────░──────────────────░──────■──────────■─────┤ H ├─░──────┼─────»
#                 ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░      │     »
# q10100_3: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░──────┼─────»
#           ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░ ┌────┴────┐»
# q10100_4: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─┤ Rz(π/8) ├»
#           └───┘ ░ └─────────┘      ░ └─────────┘                 ░ └─────────┘»
# «                                      ░                                   »
# «q10100_0: ────────────────────────────░──────■───────────■──────────■─────»
# «                                ┌───┐ ░      │           │          │     »
# «q10100_1: ─────■──────────■─────┤ H ├─░──────┼───────────┼──────────┼─────»
# «               │     ┌────┴────┐└───┘ ░      │           │     ┌────┴────┐»
# «q10100_2: ─────┼─────┤ Rz(π/2) ├──────░──────┼───────────┼─────┤ Rz(π/4) ├»
# «          ┌────┴────┐└─────────┘      ░      │      ┌────┴────┐└─────────┘»
# «q10100_3: ┤ Rz(π/4) ├─────────────────░──────┼──────┤ Rz(π/8) ├───────────»
# «          └─────────┘                 ░ ┌────┴─────┐└─────────┘           »
# «q10100_4: ────────────────────────────░─┤ Rz(π/16) ├──────────────────────»
# «                                      ░ └──────────┘                      »
# «                     ┌───┐ ░
# «q10100_0: ─────■─────┤ H ├─░─
# «          ┌────┴────┐└───┘ ░
# «q10100_1: ┤ Rz(π/2) ├──────░─
# «          └─────────┘      ░
# «q10100_2: ─────────────────░─
# «                           ░
# «q10100_3: ─────────────────░─
# «                           ░
# «q10100_4: ─────────────────░─
# «                           ░
#
# Inverse QFT Circuit =
#           ┌───┐                                                  ░      »
# q10101_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#           └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q10101_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#                └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q10101_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                            └──────────┘┌────┴─────┐      │       ░      »
# q10101_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                        └──────────┘┌─────┴─────┐ ░      »
# q10101_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                    └───────────┘ ░      »
# «                                               ░                              »
# «q10101_0: ─────────────────────────────────────░──────────────────────────────»
# «                                               ░                              »
# «q10101_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «          ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q10101_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «          └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q10101_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                      └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q10101_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                  └──────────┘ ░                  └──────────┘»
# «           ░                   ░       ░
# «q10101_0: ─░───────────────────░───────░─
# «           ░                   ░       ░
# «q10101_1: ─░───────────────────░───────░─
# «           ░                   ░       ░
# «q10101_2: ─░───────────────────░───────░─
# «           ░ ┌───┐             ░       ░
# «q10101_3: ─░─┤ H ├─────■───────░───────░─
# «           ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q10101_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «           ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Quantum Fourier Transform - Method 2

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform Benchmark Program - Qiskit
# ... using circuit method 2
# ... execution starting at Jul 11, 2022 14:52:54 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ... number of gates, depth = 9, 5
# ************
# Executing [3] circuits with num_qubits = 3
# ... number of gates, depth = 15, 8
# ************
# Executing [3] circuits with num_qubits = 4
# ... number of gates, depth = 22, 12
# ************
# Average Depth, ξ (xi) for the 2 qubit group = 6, 0.143
# Average Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.262, 2.0
# Average Creation Time for the 2 qubit group = 0.0 secs
# Average Elapsed Time for the 2 qubit group = 0.094 secs
# Average Execution Time for the 2 qubit group = 0.003 secs
# Average Fidelity for the 2 qubit group = 0.991
# Average Hellinger Fidelity for the 2 qubit group = 0.993
#
# ************
# Executing [3] circuits with num_qubits = 5
# ... number of gates, depth = 30, 17
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 9, 0.25
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 16, 0.327, 6.0
# Average Creation Time for the 3 qubit group = 0.0 secs
# Average Elapsed Time for the 3 qubit group = 0.623 secs
# Average Execution Time for the 3 qubit group = 0.004 secs
# Average Fidelity for the 3 qubit group = 0.974
# Average Hellinger Fidelity for the 3 qubit group = 0.977
#
# ************
# Executing [3] circuits with num_qubits = 6
# ... number of gates, depth = 39, 23
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 13, 0.333
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.36, 12.0
# Average Creation Time for the 4 qubit group = 0.001 secs
# Average Elapsed Time for the 4 qubit group = 1.12 secs
# Average Execution Time for the 4 qubit group = 0.004 secs
# Average Fidelity for the 4 qubit group = 0.953
# Average Hellinger Fidelity for the 4 qubit group = 0.956
#
# ************
# Executing [3] circuits with num_qubits = 7
# ... number of gates, depth = 49, 30
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 18, 0.4
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 41, 0.382, 20.0
# Average Creation Time for the 5 qubit group = 0.001 secs
# Average Elapsed Time for the 5 qubit group = 1.208 secs
# Average Execution Time for the 5 qubit group = 0.009 secs
# Average Fidelity for the 5 qubit group = 0.92
# Average Hellinger Fidelity for the 5 qubit group = 0.923
#
# ************
# Executing [3] circuits with num_qubits = 8
# ... number of gates, depth = 60, 38
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 24, 0.455
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 58, 0.395, 30.0
# Average Creation Time for the 6 qubit group = 0.001 secs
# Average Elapsed Time for the 6 qubit group = 1.298 secs
# Average Execution Time for the 6 qubit group = 0.013 secs
# Average Fidelity for the 6 qubit group = 0.88
# Average Hellinger Fidelity for the 6 qubit group = 0.882
#
# ************
# Executing [3] circuits with num_qubits = 9
# ... number of gates, depth = 72, 47
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 31, 0.5
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 78, 0.412, 42.0
# Average Creation Time for the 7 qubit group = 0.001 secs
# Average Elapsed Time for the 7 qubit group = 1.384 secs
# Average Execution Time for the 7 qubit group = 0.036 secs
# Average Fidelity for the 7 qubit group = 0.854
# Average Hellinger Fidelity for the 7 qubit group = 0.855
#
# ************
# Executing [3] circuits with num_qubits = 10
# ... number of gates, depth = 85, 57
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 39, 0.538
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 101, 0.42, 56.0
# Average Creation Time for the 8 qubit group = 0.001 secs
# Average Elapsed Time for the 8 qubit group = 1.859 secs
# Average Execution Time for the 8 qubit group = 0.123 secs
# Average Fidelity for the 8 qubit group = 0.806
# Average Hellinger Fidelity for the 8 qubit group = 0.807
#
# ************
# Average Depth, ξ (xi) for the 9 qubit group = 48, 0.571
# Average Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 127, 0.427, 72.0
# Average Creation Time for the 9 qubit group = 0.002 secs
# Average Elapsed Time for the 9 qubit group = 1.894 secs
# Average Execution Time for the 9 qubit group = 0.392 secs
# Average Fidelity for the 9 qubit group = 0.76
# Average Hellinger Fidelity for the 9 qubit group = 0.76
#
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 58, 0.6
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 156, 0.433, 90.0
# Average Creation Time for the 10 qubit group = 0.002 secs
# Average Elapsed Time for the 10 qubit group = 1.217 secs
# Average Execution Time for the 10 qubit group = 0.214 secs
# Average Fidelity for the 10 qubit group = 0.692
# Average Hellinger Fidelity for the 10 qubit group = 0.692
#
# ... execution complete at Jul 11, 2022 14:53:01 UTC in 6.998 secs
#
# Sample Circuit:
#           ┌───┐┌─────────┐ ┌──────────┐┌─┐
# q11167_0: ┤ H ├┤ Rz(10π) ├─┤0         ├┤M├────────────
#           ├───┤└┬────────┤ │          │└╥┘┌─┐
# q11167_1: ┤ H ├─┤ Rz(5π) ├─┤1         ├─╫─┤M├─────────
#           ├───┤┌┴────────┴┐│          │ ║ └╥┘┌─┐
# q11167_2: ┤ H ├┤ Rz(5π/2) ├┤2 inv_qft ├─╫──╫─┤M├──────
#           ├───┤├──────────┤│          │ ║  ║ └╥┘┌─┐
# q11167_3: ┤ H ├┤ Rz(5π/4) ├┤3         ├─╫──╫──╫─┤M├───
#           ├───┤├──────────┤│          │ ║  ║  ║ └╥┘┌─┐
# q11167_4: ┤ H ├┤ Rz(5π/8) ├┤4         ├─╫──╫──╫──╫─┤M├
#           └───┘└──────────┘└──────────┘ ║  ║  ║  ║ └╥┘
#   c240: 5/══════════════════════════════╩══╩══╩══╩══╩═
#                                         0  1  2  3  4
#
# Inverse QFT Circuit =
#           ┌───┐                                                  ░      »
# q11168_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#           └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q11168_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#                └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q11168_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                            └──────────┘┌────┴─────┐      │       ░      »
# q11168_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                        └──────────┘┌─────┴─────┐ ░      »
# q11168_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                    └───────────┘ ░      »
# «                                               ░                              »
# «q11168_0: ─────────────────────────────────────░──────────────────────────────»
# «                                               ░                              »
# «q11168_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «          ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q11168_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «          └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q11168_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                      └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q11168_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                  └──────────┘ ░                  └──────────┘»
# «           ░                   ░       ░
# «q11168_0: ─░───────────────────░───────░─
# «           ░                   ░       ░
# «q11168_1: ─░───────────────────░───────░─
# «           ░                   ░       ░
# «q11168_2: ─░───────────────────░───────░─
# «           ░ ┌───┐             ░       ░
# «q11168_3: ─░─┤ H ├─────■───────░───────░─
# «           ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q11168_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «           ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Grover

# %%
import sys
sys.path.insert(1, "grovers/qiskit")
import grovers_benchmark
grovers_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Grover's Search Benchmark Program - Qiskit
# INFO: Grover's Search benchmark is limited to a maximum of 8 qubits.
# ... execution starting at Jul 11, 2022 14:53:02 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Depth, ξ (xi) for the 2 qubit group = 13, 0.116
# Average Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 13, 0.123, 2.0
# Average Creation Time for the 2 qubit group = 0.001 secs
# Average Elapsed Time for the 2 qubit group = 0.198 secs
# Average Execution Time for the 2 qubit group = 0.003 secs
# Average Fidelity for the 2 qubit group = 0.982
# Average Hellinger Fidelity for the 2 qubit group = 0.986
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 25, 0.083
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 51, 0.303, 24.0
# Average Creation Time for the 3 qubit group = 0.001 secs
# Average Elapsed Time for the 3 qubit group = 0.987 secs
# Average Execution Time for the 3 qubit group = 0.004 secs
# Average Fidelity for the 3 qubit group = 0.954
# Average Hellinger Fidelity for the 3 qubit group = 0.969
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 36, 0.07
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 168, 0.393, 84.0
# Average Creation Time for the 4 qubit group = 0.002 secs
# Average Elapsed Time for the 4 qubit group = 2.63 secs
# Average Execution Time for the 4 qubit group = 0.01 secs
# Average Fidelity for the 4 qubit group = 0.775
# Average Hellinger Fidelity for the 4 qubit group = 0.818
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 45, 0.064
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 606, 0.379, 288.0
# Average Creation Time for the 5 qubit group = 0.003 secs
# Average Elapsed Time for the 5 qubit group = 6.243 secs
# Average Execution Time for the 5 qubit group = 0.029 secs
# Average Fidelity for the 5 qubit group = 0.256
# Average Hellinger Fidelity for the 5 qubit group = 0.287
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 66, 0.052
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 1879, 0.471, 1104.0
# Average Creation Time for the 6 qubit group = 0.005 secs
# Average Elapsed Time for the 6 qubit group = 27.525 secs
# Average Execution Time for the 6 qubit group = 0.245 secs
# Average Fidelity for the 6 qubit group = 0.019
# Average Hellinger Fidelity for the 6 qubit group = 0.052
#
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 98, 0.046
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 5062, 0.483, 3008.0
# Average Creation Time for the 7 qubit group = 0.008 secs
# Average Elapsed Time for the 7 qubit group = 87.781 secs
# Average Execution Time for the 7 qubit group = 2.476 secs
# Average Fidelity for the 7 qubit group = 0.002
# Average Hellinger Fidelity for the 7 qubit group = 0.024
#
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 146, 0.044
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 15267, 0.492, 9120.0
# Average Creation Time for the 8 qubit group = 0.012 secs
# Average Elapsed Time for the 8 qubit group = 56.82 secs
# Average Execution Time for the 8 qubit group = 22.332 secs
# Average Fidelity for the 8 qubit group = 0.0
# Average Hellinger Fidelity for the 8 qubit group = 0.004
#
# ... execution complete at Jul 11, 2022 14:54:55 UTC in 112.924 secs
#
# Sample Circuit:
#           ┌───┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ »
# q12370_0: ┤ H ├─░─┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─»
#           ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q12370_1: ┤ H ├─░─┤1        ├┤1          ├─░─┤1        ├┤1          ├─░─»
#           ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q12370_2: ┤ H ├─░─┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░─»
#           ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q12370_3: ┤ H ├─░─┤3        ├┤3          ├─░─┤3        ├┤3          ├─░─»
#           ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q12370_4: ┤ H ├─░─┤4        ├┤4          ├─░─┤4        ├┤4          ├─░─»
#           └───┘ ░ └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░ »
#   c267: 5/══════════════════════════════════════════════════════════════»
#                                                                         »
# «          ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ ┌─┐         »
# «q12370_0: ┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─┤M├─────────»
# «          │         ││           │ ░ │         ││           │ ░ └╥┘┌─┐      »
# «q12370_1: ┤1        ├┤1          ├─░─┤1        ├┤1          ├─░──╫─┤M├──────»
# «          │         ││           │ ░ │         ││           │ ░  ║ └╥┘┌─┐   »
# «q12370_2: ┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░──╫──╫─┤M├───»
# «          │         ││           │ ░ │         ││           │ ░  ║  ║ └╥┘┌─┐»
# «q12370_3: ┤3        ├┤3          ├─░─┤3        ├┤3          ├─░──╫──╫──╫─┤M├»
# «          │         ││           │ ░ │         ││           │ ░  ║  ║  ║ └╥┘»
# «q12370_4: ┤4        ├┤4          ├─░─┤4        ├┤4          ├─░──╫──╫──╫──╫─»
# «          └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░  ║  ║  ║  ║ »
# «  c267: 5/═══════════════════════════════════════════════════════╩══╩══╩══╩═»
# «                                                                 0  1  2  3 »
# «
# «q12370_0: ───
# «
# «q12370_1: ───
# «
# «q12370_2: ───
# «
# «q12370_3: ───
# «          ┌─┐
# «q12370_4: ┤M├
# «          └╥┘
# «  c267: 5/═╩═
# «           4
#
# Oracle =
#           ┌───┐           ░ ┌───┐
# q12377_0: ┤ X ├──■────────░─┤ X ├
#           └───┘  │        ░ └───┘
# q12377_1: ───────■────────░──────
#                  │        ░
# q12377_2: ───────■────────░──────
#           ┌───┐  │        ░ ┌───┐
# q12377_3: ┤ X ├──■────────░─┤ X ├
#           ├───┤┌─┴─┐┌───┐ ░ └───┘
# q12377_4: ┤ H ├┤ X ├┤ H ├─░──────
#           └───┘└───┘└───┘ ░
#
# Diffuser =
#           ┌───┐┌───┐                ░ ┌───┐┌───┐
# q12378_0: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#           ├───┤├───┤       │        ░ ├───┤├───┤
# q12378_1: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#           ├───┤├───┤       │        ░ ├───┤├───┤
# q12378_2: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#           ├───┤├───┤       │        ░ ├───┤├───┤
# q12378_3: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#           ├───┤├───┤┌───┐┌─┴─┐┌───┐ ░ ├───┤├───┤
# q12378_4: ┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├┤ H ├
#           └───┘└───┘└───┘└───┘└───┘ ░ └───┘└───┘

# %% [markdown]
# ### Phase Estimation

# %%
import sys
sys.path.insert(1, "phase-estimation/qiskit")
import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Jul 11, 2022 14:54:56 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 16, 0.316
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 14, 0.207, 4.0
# Average Creation Time for the 3 qubit group = 0.002 secs
# Average Elapsed Time for the 3 qubit group = 0.093 secs
# Average Execution Time for the 3 qubit group = 0.003 secs
# Average Fidelity for the 3 qubit group = 0.979
# Average Hellinger Fidelity for the 3 qubit group = 0.984
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 27, 0.353
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 30, 0.295, 11.333
# Average Creation Time for the 4 qubit group = 0.003 secs
# Average Elapsed Time for the 4 qubit group = 0.336 secs
# Average Execution Time for the 4 qubit group = 0.004 secs
# Average Fidelity for the 4 qubit group = 0.944
# Average Hellinger Fidelity for the 4 qubit group = 0.951
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 41, 0.377
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 43, 0.324, 18.667
# Average Creation Time for the 5 qubit group = 0.003 secs
# Average Elapsed Time for the 5 qubit group = 0.962 secs
# Average Execution Time for the 5 qubit group = 0.005 secs
# Average Fidelity for the 5 qubit group = 0.92
# Average Hellinger Fidelity for the 5 qubit group = 0.925
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 58, 0.395
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 59, 0.344, 27.333
# Average Creation Time for the 6 qubit group = 0.004 secs
# Average Elapsed Time for the 6 qubit group = 1.371 secs
# Average Execution Time for the 6 qubit group = 0.013 secs
# Average Fidelity for the 6 qubit group = 0.894
# Average Hellinger Fidelity for the 6 qubit group = 0.897
#
# ************
# Executing [3] circuits with num_qubits = 9
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 78, 0.408
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 82, 0.364, 40.667
# Average Creation Time for the 7 qubit group = 0.005 secs
# Average Elapsed Time for the 7 qubit group = 1.653 secs
# Average Execution Time for the 7 qubit group = 0.04 secs
# Average Fidelity for the 7 qubit group = 0.828
# Average Hellinger Fidelity for the 7 qubit group = 0.831
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 101, 0.418
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 109, 0.378, 56.0
# Average Creation Time for the 8 qubit group = 0.005 secs
# Average Elapsed Time for the 8 qubit group = 2.451 secs
# Average Execution Time for the 8 qubit group = 0.174 secs
# Average Fidelity for the 8 qubit group = 0.797
# Average Hellinger Fidelity for the 8 qubit group = 0.799
#
# ************
# Average Depth, ξ (xi) for the 9 qubit group = 127, 0.426
# Average Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 127, 0.388, 67.333
# Average Creation Time for the 9 qubit group = 0.006 secs
# Average Elapsed Time for the 9 qubit group = 2.111 secs
# Average Execution Time for the 9 qubit group = 0.512 secs
# Average Fidelity for the 9 qubit group = 0.745
# Average Hellinger Fidelity for the 9 qubit group = 0.746
#
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 156, 0.433
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 163, 0.398, 88.667
# Average Creation Time for the 10 qubit group = 0.008 secs
# Average Elapsed Time for the 10 qubit group = 1.235 secs
# Average Execution Time for the 10 qubit group = 0.215 secs
# Average Fidelity for the 10 qubit group = 0.689
# Average Hellinger Fidelity for the 10 qubit group = 0.69
#
# ... execution complete at Jul 11, 2022 14:55:02 UTC in 6.753 secs
#
# Sample Circuit:
#           ┌───┐ ░                              ░ ┌──────────┐ ░ ┌─┐
# q13390_0: ┤ H ├─░─────────────────────────■────░─┤0         ├─░─┤M├─────────
#           ├───┤ ░                         │    ░ │          │ ░ └╥┘┌─┐
# q13390_1: ┤ H ├─░──────────────────■──────┼────░─┤1         ├─░──╫─┤M├──────
#           ├───┤ ░                  │      │    ░ │  inv_qft │ ░  ║ └╥┘┌─┐
# q13390_2: ┤ H ├─░───────────■──────┼──────┼────░─┤2         ├─░──╫──╫─┤M├───
#           ├───┤ ░           │      │      │    ░ │          │ ░  ║  ║ └╥┘┌─┐
# q13390_3: ┤ H ├─░────■──────┼──────┼──────┼────░─┤3         ├─░──╫──╫──╫─┤M├
#           ├───┤ ░ ┌──┴──┐┌──┴──┐┌──┴──┐┌──┴──┐ ░ └──────────┘ ░  ║  ║  ║ └╥┘
# q13390_4: ┤ X ├─░─┤ U^1 ├┤ U^2 ├┤ U^4 ├┤ U^8 ├─░──────────────░──╫──╫──╫──╫─
#           └───┘ ░ └─────┘└─────┘└─────┘└─────┘ ░              ░  ║  ║  ║  ║
#   c284: 4/═══════════════════════════════════════════════════════╩══╩══╩══╩═
#                                                                  0  1  2  3
#
# Phase Operator 'U' =
#    ┌────────┐
# q: ┤ P(π/4) ├
#    └────────┘
#
# Inverse QFT Circuit =
#           ┌───┐                                     ░                  »
# q13392_0: ┤ H ├─────■───────────■───────────■───────░──────────────────»
#           └───┘┌────┴─────┐     │           │       ░ ┌───┐            »
# q13392_1: ─────┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■──────»
#                └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐»
# q13392_2: ─────────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├»
#                            └──────────┘┌────┴─────┐ ░      └──────────┘»
# q13392_3: ─────────────────────────────┤ Rz(-π/8) ├─░──────────────────»
#                                        └──────────┘ ░                  »
# «                       ░                   ░       ░
# «q13392_0: ─────────────░───────────────────░───────░─
# «                       ░                   ░       ░
# «q13392_1: ─────■───────░───────────────────░───────░─
# «               │       ░ ┌───┐             ░       ░
# «q13392_2: ─────┼───────░─┤ H ├─────■───────░───────░─
# «          ┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q13392_3: ┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «          └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Amplitude Estimation

# %%
import sys
sys.path.insert(1, "amplitude-estimation/qiskit")
import ae_benchmark
ae_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# INFO: Amplitude Estimation benchmark is limited to a maximum of 8 qubits.
# ... execution starting at Jul 11, 2022 14:55:03 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation Time for the 3 qubit group = 0.008 secs
# Average Elapsed Time for the 3 qubit group = 0.486 secs
# Average Execution Time for the 3 qubit group = 0.004 secs
# Average Fidelity for the 3 qubit group = 0.847
# Average Hellinger Fidelity for the 3 qubit group = 0.924
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation Time for the 4 qubit group = 0.013 secs
# Average Elapsed Time for the 4 qubit group = 2.363 secs
# Average Execution Time for the 4 qubit group = 0.006 secs
# Average Fidelity for the 4 qubit group = 0.655
# Average Hellinger Fidelity for the 4 qubit group = 0.804
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation Time for the 5 qubit group = 0.023 secs
# Average Elapsed Time for the 5 qubit group = 5.229 secs
# Average Execution Time for the 5 qubit group = 0.024 secs
# Average Fidelity for the 5 qubit group = 0.494
# Average Hellinger Fidelity for the 5 qubit group = 0.621
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation Time for the 6 qubit group = 0.018 secs
# Average Elapsed Time for the 6 qubit group = 12.655 secs
# Average Execution Time for the 6 qubit group = 0.101 secs
# Average Fidelity for the 6 qubit group = 0.292
# Average Hellinger Fidelity for the 6 qubit group = 0.367
#
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation Time for the 7 qubit group = 0.068 secs
# Average Elapsed Time for the 7 qubit group = 26.164 secs
# Average Execution Time for the 7 qubit group = 0.739 secs
# Average Fidelity for the 7 qubit group = 0.098
# Average Hellinger Fidelity for the 7 qubit group = 0.155
#
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation Time for the 8 qubit group = 0.103 secs
# Average Elapsed Time for the 8 qubit group = 16.624 secs
# Average Execution Time for the 8 qubit group = 5.216 secs
# Average Fidelity for the 8 qubit group = 0.067
# Average Hellinger Fidelity for the 8 qubit group = 0.096
#
# ... execution complete at Jul 11, 2022 14:55:44 UTC in 40.13 secs
#
# Sample Circuit:
#           ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q14745_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#           ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q14745_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#           ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q14745_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#           ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q14744_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#           │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q14744_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#           └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#   c307: 3/═════════════════════════════════════════════════════════════════»
#                                                                            »
# «          ┌──────────┐ ░ ┌─┐
# «q14745_0: ┤0         ├─░─┤M├──────
# «          │          │ ░ └╥┘┌─┐
# «q14745_1: ┤1 inv_qft ├─░──╫─┤M├───
# «          │          │ ░  ║ └╥┘┌─┐
# «q14745_2: ┤2         ├─░──╫──╫─┤M├
# «          └──────────┘ ░  ║  ║ └╥┘
# «q14744_0: ─────────────░──╫──╫──╫─
# «                       ░  ║  ║  ║
# «q14744_1: ─────────────░──╫──╫──╫─
# «                       ░  ║  ║  ║
# «  c307: 3/════════════════╩══╩══╩═
# «                          0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q15294: ──■───
#         ┌─┴──┐
#    q_0: ┤0   ├
#         │  Q │
#    q_1: ┤1   ├
#         └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#           ┌───┐                         ░                   ░       ░
# q14747_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#           └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q14747_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#                └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q14747_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                            └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Monte Carlo

# %%
import sys
sys.path.insert(1, "monte-carlo/qiskit")
import mc_benchmark
mc_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Monte Carlo Sampling Benchmark Program - Qiskit
# ... using circuit method 2
# ... execution starting at Jul 11, 2022 14:55:45 UTC
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 202, 0.398
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 208, 0.372, 96.0
# Average Creation Time for the 4 qubit group = 0.011 secs
# Average Elapsed Time for the 4 qubit group = 0.662 secs
# Average Execution Time for the 4 qubit group = 0.019 secs
# Average Fidelity for the 4 qubit group = 0.568
# Average Hellinger Fidelity for the 4 qubit group = 0.784
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 468, 0.401
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 479, 0.377, 224.0
# Average Creation Time for the 5 qubit group = 0.022 secs
# Average Elapsed Time for the 5 qubit group = 1.499 secs
# Average Execution Time for the 5 qubit group = 0.024 secs
# Average Fidelity for the 5 qubit group = 0.372
# Average Hellinger Fidelity for the 5 qubit group = 0.529
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 997, 0.402
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 1017, 0.38, 478.0
# Average Creation Time for the 6 qubit group = 0.023 secs
# Average Elapsed Time for the 6 qubit group = 3.158 secs
# Average Execution Time for the 6 qubit group = 0.117 secs
# Average Fidelity for the 6 qubit group = 0.257
# Average Hellinger Fidelity for the 6 qubit group = 0.35
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 2049, 0.402
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 2086, 0.382, 982.0
# Average Creation Time for the 7 qubit group = 0.04 secs
# Average Elapsed Time for the 7 qubit group = 7.129 secs
# Average Execution Time for the 7 qubit group = 0.843 secs
# Average Fidelity for the 7 qubit group = 0.135
# Average Hellinger Fidelity for the 7 qubit group = 0.189
#
# ************
# Executing [3] circuits with num_qubits = 9
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 4144, 0.403
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 4214, 0.382, 1984.0
# Average Creation Time for the 8 qubit group = 0.075 secs
# Average Elapsed Time for the 8 qubit group = 18.886 secs
# Average Execution Time for the 8 qubit group = 6.42 secs
# Average Fidelity for the 8 qubit group = 0.062
# Average Hellinger Fidelity for the 8 qubit group = 0.091
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Depth, ξ (xi) for the 9 qubit group = 8322, 0.403
# Average Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 8457, 0.383, 3980.0
# Average Creation Time for the 9 qubit group = 0.151 secs
# Average Elapsed Time for the 9 qubit group = 66.404 secs
# Average Execution Time for the 9 qubit group = 26.499 secs
# Average Fidelity for the 9 qubit group = 0.042
# Average Hellinger Fidelity for the 9 qubit group = 0.057
#
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 16663, 0.403
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 16927, 0.383, 7962.0
# Average Creation Time for the 10 qubit group = 0.288 secs
# Average Elapsed Time for the 10 qubit group = 29.191 secs
# Average Execution Time for the 10 qubit group = 14.989 secs
# Average Fidelity for the 10 qubit group = 0.012
# Average Hellinger Fidelity for the 10 qubit group = 0.02
#
# ... execution complete at Jul 11, 2022 14:57:09 UTC in 84.157 secs
#
# Sample Circuit:
#           ┌────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q15588_0: ┤0   ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#           │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q15588_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├─░─»
#           ├───┬┘│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q15589_0: ┤ H ├─┤  c_Q ├┤      ├┤      ├┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#           ├───┤ │      ││      ││      │└──────┘└──────┘└──────┘└──────┘ ░ »
# q15589_1: ┤ H ├─┤      ├┤0     ├┤0     ├─────────────────────────────────░─»
#           ├───┤ │      │└──────┘└──────┘                                 ░ »
# q15589_2: ┤ H ├─┤0     ├─────────────────────────────────────────────────░─»
#           └───┘ └──────┘                                                 ░ »
#   c318: 3/═════════════════════════════════════════════════════════════════»
#                                                                            »
# «                       ░
# «q15588_0: ─────────────░──────────
# «                       ░
# «q15588_1: ─────────────░──────────
# «          ┌──────────┐ ░ ┌─┐
# «q15589_0: ┤0         ├─░─┤M├──────
# «          │          │ ░ └╥┘┌─┐
# «q15589_1: ┤1 inv_qft ├─░──╫─┤M├───
# «          │          │ ░  ║ └╥┘┌─┐
# «q15589_2: ┤2         ├─░──╫──╫─┤M├
# «          └──────────┘ ░  ║  ║ └╥┘
# «  c318: 3/════════════════╩══╩══╩═
# «                          0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q15936: ──■───
#         ┌─┴──┐
#    q_0: ┤0   ├
#         │  Q │
#    q_1: ┤1   ├
#         └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#           ┌────┐┌────┐
# q15931_0: ┤0   ├┤0   ├
#           │  R ││  F │
# q15931_1: ┤1   ├┤1   ├
#           └────┘└────┘
#
# Distribution Generator 'R' =
#           ┌───┐
# q15932_0: ┤ H ├
#           └───┘
# q15932_1: ─────
#
#
# Function Generator 'F' =
#
# q15933_0: ──■──
#           ┌─┴─┐
# q15933_1: ┤ X ├
#           └───┘
#
# Inverse QFT Circuit =
#           ┌───┐                         ░                   ░       ░
# q15591_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#           └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q15591_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#                └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q15591_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                            └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Hamiltonian Simulation

# %%
import sys
sys.path.insert(1, "hamiltonian-simulation/qiskit")
import hamiltonian_simulation_benchmark
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hamiltonian-Simulation Benchmark Program - Qiskit
# ... execution starting at Jul 11, 2022 14:57:10 UTC
# ************
# Executing [1] circuits with num_qubits = 2
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Average Depth, ξ (xi) for the 2 qubit group = 29, 0.243
# Average Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 29, 0.243, 9.0
# Average Creation Time for the 2 qubit group = 0.001 secs
# Average Elapsed Time for the 2 qubit group = 0.092 secs
# Average Execution Time for the 2 qubit group = 0.004 secs
# Average Fidelity for the 2 qubit group = 0.937
# Average Hellinger Fidelity for the 2 qubit group = 0.954
#
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 44, 0.265
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 44, 0.265, 18.0
# Average Creation Time for the 3 qubit group = 0.002 secs
# Average Elapsed Time for the 3 qubit group = 0.127 secs
# Average Execution Time for the 3 qubit group = 0.004 secs
# Average Fidelity for the 3 qubit group = 0.913
# Average Hellinger Fidelity for the 3 qubit group = 0.925
#
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 50, 0.276
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 44, 0.293, 27.0
# Average Creation Time for the 4 qubit group = 0.003 secs
# Average Elapsed Time for the 4 qubit group = 0.162 secs
# Average Execution Time for the 4 qubit group = 0.004 secs
# Average Fidelity for the 4 qubit group = 0.884
# Average Hellinger Fidelity for the 4 qubit group = 0.893
#
# ************
# Executing [1] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 50, 0.279
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 44, 0.293, 36.0
# Average Creation Time for the 5 qubit group = 0.003 secs
# Average Elapsed Time for the 5 qubit group = 0.194 secs
# Average Execution Time for the 5 qubit group = 0.007 secs
# Average Fidelity for the 5 qubit group = 0.892
# Average Hellinger Fidelity for the 5 qubit group = 0.898
#
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 50, 0.283
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 44, 0.306, 45.0
# Average Creation Time for the 6 qubit group = 0.004 secs
# Average Elapsed Time for the 6 qubit group = 0.237 secs
# Average Execution Time for the 6 qubit group = 0.015 secs
# Average Fidelity for the 6 qubit group = 0.856
# Average Hellinger Fidelity for the 6 qubit group = 0.86
#
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 50, 0.284
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 44, 0.303, 54.0
# Average Creation Time for the 7 qubit group = 0.005 secs
# Average Elapsed Time for the 7 qubit group = 0.31 secs
# Average Execution Time for the 7 qubit group = 0.054 secs
# Average Fidelity for the 7 qubit group = 0.85
# Average Hellinger Fidelity for the 7 qubit group = 0.852
#
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 50, 0.286
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 44, 0.312, 63.0
# Average Creation Time for the 8 qubit group = 0.005 secs
# Average Elapsed Time for the 8 qubit group = 0.563 secs
# Average Execution Time for the 8 qubit group = 0.261 secs
# Average Fidelity for the 8 qubit group = 0.808
# Average Hellinger Fidelity for the 8 qubit group = 0.81
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Depth, ξ (xi) for the 9 qubit group = 50, 0.287
# Average Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 44, 0.309, 72.0
# Average Creation Time for the 9 qubit group = 0.006 secs
# Average Elapsed Time for the 9 qubit group = 0.82 secs
# Average Execution Time for the 9 qubit group = 0.456 secs
# Average Fidelity for the 9 qubit group = 0.803
# Average Hellinger Fidelity for the 9 qubit group = 0.804
#
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 50, 0.288
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 44, 0.315, 81.0
# Average Creation Time for the 10 qubit group = 0.007 secs
# Average Elapsed Time for the 10 qubit group = 0.433 secs
# Average Execution Time for the 10 qubit group = 0.249 secs
# Average Fidelity for the 10 qubit group = 0.765
# Average Hellinger Fidelity for the 10 qubit group = 0.766
#
# ... execution complete at Jul 11, 2022 14:57:12 UTC in 2.071 secs
#
# Sample Circuit:
#           ┌───┐ ░ ┌───────────────┐ ┌──────────────┐ ░ ┌─────────────┐»
# q16202_0: ┤ X ├─░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─┤0            ├»
#           └───┘ ░ ├───────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q16202_1: ──────░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─┤1            ├»
#           ┌───┐ ░ └┬──────────────┤└┬──────────────┤ ░ ├─────────────┤»
# q16202_2: ┤ X ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─┤0            ├»
#           └───┘ ░  ├──────────────┤ ├──────────────┤ ░ │  xxyyzz_opt │»
# q16202_3: ──────░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─┤1            ├»
#           ┌───┐ ░  ├──────────────┤ ├──────────────┤ ░ ├─────────────┤»
# q16202_4: ┤ X ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─┤0            ├»
#           └───┘ ░  ├──────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q16202_5: ──────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─┤1            ├»
#                 ░  └──────────────┘└───────────────┘ ░ └─────────────┘»
#   c328: 6/════════════════════════════════════════════════════════════»
#                                                                       »
# «                          ░ ┌───────────────┐ ┌──────────────┐ ░ »
# «q16202_0: ────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─»
# «          ┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤ ░ »
# «q16202_1: ┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─»
# «          │  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤ ░ »
# «q16202_2: ┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─»
# «          ├─────────────┤ ░  ├──────────────┤ ├──────────────┤ ░ »
# «q16202_3: ┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─»
# «          │  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤ ░ »
# «q16202_4: ┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─»
# «          └─────────────┘ ░  ├──────────────┤┌┴──────────────┤ ░ »
# «q16202_5: ────────────────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─»
# «                          ░  └──────────────┘└───────────────┘ ░ »
# «  c328: 6/═══════════════════════════════════════════════════════»
# «                                                                 »
# «          ┌─────────────┐                ░ ┌───────────────┐ ┌──────────────┐»
# «q16202_0: ┤0            ├────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├»
# «          │  xxyyzz_opt │┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤»
# «q16202_1: ┤1            ├┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├»
# «          ├─────────────┤│  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤»
# «q16202_2: ┤0            ├┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├»
# «          │  xxyyzz_opt │├─────────────┤ ░  ├──────────────┤ ├──────────────┤»
# «q16202_3: ┤1            ├┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├»
# «          ├─────────────┤│  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤»
# «q16202_4: ┤0            ├┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├»
# «          │  xxyyzz_opt │└─────────────┘ ░  ├──────────────┤┌┴──────────────┤»
# «q16202_5: ┤1            ├────────────────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├»
# «          └─────────────┘                ░  └──────────────┘└───────────────┘»
# «  c328: 6/═══════════════════════════════════════════════════════════════════»
# «                                                                             »
# «           ░ ┌─────────────┐                ░ ┌─┐
# «q16202_0: ─░─┤0            ├────────────────░─┤M├───────────────
# «           ░ │  xxyyzz_opt │┌─────────────┐ ░ └╥┘┌─┐
# «q16202_1: ─░─┤1            ├┤0            ├─░──╫─┤M├────────────
# «           ░ ├─────────────┤│  xxyyzz_opt │ ░  ║ └╥┘┌─┐
# «q16202_2: ─░─┤0            ├┤1            ├─░──╫──╫─┤M├─────────
# «           ░ │  xxyyzz_opt │├─────────────┤ ░  ║  ║ └╥┘┌─┐
# «q16202_3: ─░─┤1            ├┤0            ├─░──╫──╫──╫─┤M├──────
# «           ░ ├─────────────┤│  xxyyzz_opt │ ░  ║  ║  ║ └╥┘┌─┐
# «q16202_4: ─░─┤0            ├┤1            ├─░──╫──╫──╫──╫─┤M├───
# «           ░ │  xxyyzz_opt │└─────────────┘ ░  ║  ║  ║  ║ └╥┘┌─┐
# «q16202_5: ─░─┤1            ├────────────────░──╫──╫──╫──╫──╫─┤M├
# «           ░ └─────────────┘                ░  ║  ║  ║  ║  ║ └╥┘
# «  c328: 6/═════════════════════════════════════╩══╩══╩══╩══╩══╩═
# «                                               0  1  2  3  4  5
#
# XXYYZZ_opt =
#                         ┌───┐┌─────────────┐                    ┌───┐»
# q16479_0: ──────────────┤ X ├┤ Rz(-1.5603) ├──■─────────────────┤ X ├»
#           ┌────────────┐└─┬─┘└┬────────────┤┌─┴─┐┌─────────────┐└─┬─┘»
# q16479_1: ┤ Rz(1.5708) ├──■───┤ Ry(1.5603) ├┤ X ├┤ Ry(-1.5603) ├──■──»
#           └────────────┘      └────────────┘└───┘└─────────────┘     »
# «          ┌─────────────┐
# «q16479_0: ┤ Rz(-1.5708) ├
# «          └─────────────┘
# «q16479_1: ───────────────
# «

# %% [markdown]
# ### VQE - Method 1

# %%
import sys
sys.path.insert(1, "vqe/qiskit")
import vqe_benchmark
vqe_num_shots=4098
vqe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=vqe_num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Variational Quantum Eigensolver Benchmark Program - Qiskit
# ... using circuit method 1
# ... execution starting at Jul 11, 2022 14:57:13 UTC
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 5, 0
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 76, 0.533, 56.0
# Average Creation Time for the 4 qubit group = 0.091 secs
# Average Elapsed Time for the 4 qubit group = 2.388 secs
# Average Execution Time for the 4 qubit group = 0.017 secs
# Average Fidelity for the 4 qubit group = 0.805
# Average Hellinger Fidelity for the 4 qubit group = 0.84
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 10, 0
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 341, 0.63, 272.0
# Average Creation Time for the 6 qubit group = 0.388 secs
# Average Elapsed Time for the 6 qubit group = 23.284 secs
# Average Execution Time for the 6 qubit group = 0.066 secs
# Average Fidelity for the 6 qubit group = 0.372
# Average Hellinger Fidelity for the 6 qubit group = 0.414
#
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 26, 0
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 1543, 0.692, 1280.0
# Average Creation Time for the 8 qubit group = 1.953 secs
# Average Elapsed Time for the 8 qubit group = 90.125 secs
# Average Execution Time for the 8 qubit group = 2.654 secs
# Average Fidelity for the 8 qubit group = 0.019
# Average Hellinger Fidelity for the 8 qubit group = 0.075
#
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 50, 0
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 3932, 0.733, 3360.0
# Average Creation Time for the 10 qubit group = 2.454 secs
# Average Elapsed Time for the 10 qubit group = 69.638 secs
# Average Execution Time for the 10 qubit group = 31.036 secs
# Average Fidelity for the 10 qubit group = 0.001
# Average Hellinger Fidelity for the 10 qubit group = 0.033
#
# ... execution complete at Jul 11, 2022 14:59:11 UTC in 118.387 secs
#
# Sample Circuit:
#           ┌─────┐┌────────────────────┐┌────────────────────┐»
# q16524_0: ┤0    ├┤0                   ├┤0                   ├»
#           │     ││                    ││                    │»
# q16524_1: ┤1    ├┤1                   ├┤1                   ├»
#           │  Hf ││  Cluster Op (0, 1) ││  Cluster Op (2, 3) │»
# q16524_2: ┤2    ├┤2                   ├┤2                   ├»
#           │     ││                    ││                    │»
# q16524_3: ┤3    ├┤3                   ├┤3                   ├»
#           └─────┘└────────────────────┘└────────────────────┘»
#   meas: 4/═══════════════════════════════════════════════════»
#                                                              »
# «          ┌──────────────────────────┐ ░ ┌─┐
# «q16524_0: ┤0                         ├─░─┤M├─────────
# «          │                          │ ░ └╥┘┌─┐
# «q16524_1: ┤1                         ├─░──╫─┤M├──────
# «          │  Cluster Op (0, 1, 2, 3) │ ░  ║ └╥┘┌─┐
# «q16524_2: ┤2                         ├─░──╫──╫─┤M├───
# «          │                          │ ░  ║  ║ └╥┘┌─┐
# «q16524_3: ┤3                         ├─░──╫──╫──╫─┤M├
# «          └──────────────────────────┘ ░  ║  ║  ║ └╥┘
# «  meas: 4/════════════════════════════════╩══╩══╩══╩═
# «                                          0  1  2  3
#
# Hartree Fock Generator 'Hf' =
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘
# q_3: ─────
#
#
# Cluster Operator Example 'Cluster Op' =
#      ┌──────────────────────────────────────────────────────────────────────┐
# q_0: ┤0                                                                     ├
#      │                                                                      │
# q_1: ┤1                                                                     ├
#      │  exp(-it (YXXX + XYXX + XXYX + YYYX + XXXY + YYXY + YXYY + XYYY))(1) │
# q_2: ┤2                                                                     ├
#      │                                                                      │
# q_3: ┤3                                                                     ├
#      └──────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Shor - Method 1

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding Algorithm Benchmark - Qiskit
# ... using circuit method 1
# ... execution starting at Jul 11, 2022 14:59:12 UTC
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 904, 0.536
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 2732, 0.425, 1644.0
# Average Creation Time for the 10 qubit group = 0.22 secs
# Average Elapsed Time for the 10 qubit group = 5.915 secs
# Average Execution Time for the 10 qubit group = 3.067 secs
# Average Fidelity for the 10 qubit group = 0.017
# Average Hellinger Fidelity for the 10 qubit group = 0.14
#
# ... execution complete at Jul 11, 2022 14:59:19 UTC in 6.762 secs
#
# Sample Circuit:
#           ┌───┐ ░                                ┌──────────┐ ░ ┌──────────┐┌─┐»
# q17191_0: ┤ H ├─░────────────────────────────────┤0         ├─░─┤0         ├┤M├»
#           ├───┤ ░                     ┌─────────┐│          │ ░ │          │└╥┘»
# q17191_1: ┤ H ├─░─────────────────────┤0        ├┤          ├─░─┤1         ├─╫─»
#           ├───┤ ░           ┌────────┐│         ││          │ ░ │  inv_qft │ ║ »
# q17191_2: ┤ H ├─░───────────┤0       ├┤         ├┤          ├─░─┤2         ├─╫─»
#           ├───┤ ░ ┌────────┐│        ││         ││          │ ░ │          │ ║ »
# q17191_3: ┤ H ├─░─┤0       ├┤        ├┤         ├┤          ├─░─┤3         ├─╫─»
#           ├───┤ ░ │        ││        ││         ││          │ ░ └──────────┘ ║ »
# q17192_0: ┤ X ├─░─┤1       ├┤1       ├┤1        ├┤1         ├─░──────────────╫─»
#           └───┘ ░ │        ││        ││         ││  C-U^256 │ ░              ║ »
# q17192_1: ──────░─┤2       ├┤2       ├┤2 C-U^16 ├┤2         ├─░──────────────╫─»
#                 ░ │        ││  C-U^4 ││         ││          │ ░              ║ »
# q17193_0: ──────░─┤3 C-U^2 ├┤3       ├┤3        ├┤3         ├─░──────────────╫─»
#                 ░ │        ││        ││         ││          │ ░              ║ »
# q17193_1: ──────░─┤4       ├┤4       ├┤4        ├┤4         ├─░──────────────╫─»
#                 ░ │        ││        ││         ││          │ ░              ║ »
# q17193_2: ──────░─┤5       ├┤5       ├┤5        ├┤5         ├─░──────────────╫─»
#                 ░ │        ││        ││         ││          │ ░              ║ »
# q17193_3: ──────░─┤6       ├┤6       ├┤6        ├┤6         ├─░──────────────╫─»
#                 ░ └────────┘└────────┘└─────────┘└──────────┘ ░              ║ »
#   c333: 4/═══════════════════════════════════════════════════════════════════╩═»
#                                                                              0 »
# «
# «q17191_0: ─────────
# «          ┌─┐
# «q17191_1: ┤M├──────
# «          └╥┘┌─┐
# «q17191_2: ─╫─┤M├───
# «           ║ └╥┘┌─┐
# «q17191_3: ─╫──╫─┤M├
# «           ║  ║ └╥┘
# «q17192_0: ─╫──╫──╫─
# «           ║  ║  ║
# «q17192_1: ─╫──╫──╫─
# «           ║  ║  ║
# «q17193_0: ─╫──╫──╫─
# «           ║  ║  ║
# «q17193_1: ─╫──╫──╫─
# «           ║  ║  ║
# «q17193_2: ─╫──╫──╫─
# «           ║  ║  ║
# «q17193_3: ─╫──╫──╫─
# «           ║  ║  ║
# «  c333: 4/═╩══╩══╩═
# «           1  2  3
#
# Controlled Ua Operator 'cUa' =
#           ┌─────────────┐      ┌─────────────────┐
#   q17326: ┤0            ├─■──■─┤0                ├
#           │             │ │  │ │                 │
# q17327_0: ┤1            ├─X──┼─┤1                ├
#           │             │ │  │ │                 │
# q17327_1: ┤2            ├─┼──X─┤2                ├
#           │             │ │  │ │                 │
# q17328_0: ┤3 cMULTamodN ├─X──┼─┤3 inv_cMULTamodN ├
#           │             │    │ │                 │
# q17328_1: ┤4            ├────X─┤4                ├
#           │             │      │                 │
# q17329_0: ┤5            ├──────┤5                ├
#           │             │      │                 │
# q17329_1: ┤6            ├──────┤6                ├
#           └─────────────┘      └─────────────────┘
#
# Controlled Multiplier Operator 'cMULTamodN' =
#                   ┌─────────────┐┌─────────────┐
#   q17350: ────────┤0            ├┤0            ├────────────
#                   │             ││             │
# q17351_0: ────────┤1            ├┤             ├────────────
#                   │             ││             │
# q17351_1: ────────┤             ├┤1            ├────────────
#           ┌──────┐│             ││             │┌──────────┐
# q17352_0: ┤0     ├┤2 ccφADDmodN ├┤2 ccφADDmodN ├┤0         ├
#           │      ││             ││             ││          │
# q17352_1: ┤1 qft ├┤3            ├┤3            ├┤1 inv_qft ├
#           │      ││             ││             ││          │
# q17352_2: ┤2     ├┤4            ├┤4            ├┤2         ├
#           └──────┘│             ││             │└──────────┘
#   q17353: ────────┤5            ├┤5            ├────────────
#                   └─────────────┘└─────────────┘
#
# Controlled Modular Adder Operator 'ccphiamodN' =
#                                                                               »
# q17362_0: ────■────────────────────────────────────────────────────────■──────»
#               │                                                        │      »
# q17362_1: ────■────────────────────────────────────────────────────────■──────»
#           ┌───┴───┐┌───────────┐┌──────────┐     ┌──────┐┌───────┐┌────┴─────┐»
# q17363_0: ┤0      ├┤0          ├┤0         ├─────┤0     ├┤0      ├┤0         ├»
#           │       ││           ││          │     │      ││       ││          │»
# q17363_1: ┤1 φADD ├┤1 inv_φADD ├┤1 inv_qft ├─────┤1 qft ├┤1 φADD ├┤1 φADD_dg ├»
#           │       ││           ││          │     │      ││       ││          │»
# q17363_2: ┤2      ├┤2          ├┤2         ├──■──┤2     ├┤2      ├┤2         ├»
#           └───────┘└───────────┘└──────────┘┌─┴─┐└──────┘└───┬───┘└──────────┘»
#   q17364: ──────────────────────────────────┤ X ├────────────■────────────────»
#                                             └───┘                             »
# «
# «q17362_0: ───────────────────────────────────────■────
# «                                                 │
# «q17362_1: ───────────────────────────────────────■────
# «          ┌──────────┐               ┌──────┐┌───┴───┐
# «q17363_0: ┤0         ├───────────────┤0     ├┤0      ├
# «          │          │               │      ││       │
# «q17363_1: ┤1 inv_qft ├───────────────┤1 qft ├┤1 φADD ├
# «          │          │┌───┐     ┌───┐│      ││       │
# «q17363_2: ┤2         ├┤ X ├──■──┤ X ├┤2     ├┤2      ├
# «          └──────────┘└───┘┌─┴─┐└───┘└──────┘└───────┘
# «  q17364: ─────────────────┤ X ├──────────────────────
# «                           └───┘
#
# Phi Adder Operator 'φADD' =
#        ┌──────┐
# q_0: ──┤ P(π) ├─
#      ┌─┴──────┴┐
# q_1: ┤ P(3π/2) ├
#      ├─────────┤
# q_2: ┤ P(3π/4) ├
#      └─────────┘
#
# QFT Circuit =
#                 ░                  ░                       ┌───┐ ░
# q17371_0: ──────░──────────────────░──────■──────────■─────┤ H ├─░─
#                 ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░
# q17371_1: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░─
#           ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░
# q17371_2: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─
#           └───┘ ░ └─────────┘      ░ └─────────┘                 ░

# %% [markdown]
# ### Shor - Method 2

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding Algorithm Benchmark - Qiskit
# ... using circuit method 2
# ... execution starting at Jul 10, 2022 22:50:03 UTC
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 881, 0.527
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 2752, 0.413, 1632.0
# Average Creation Time for the 7 qubit group = 0.28 secs
# Average Elapsed Time for the 7 qubit group = 5.7 secs
# Average Execution Time for the 7 qubit group = 3.031 secs
# Average Fidelity for the 7 qubit group = 0.045
# Average Hellinger Fidelity for the 7 qubit group = 0.165
#
# ... execution complete at Jul 10, 2022 22:50:09 UTC in 6.495 secs
#
# Sample Circuit:
#                ░  ┌───┐ ┌───┐┌──────────┐┌──────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐»
#   q8335: ──────░──┤ X ├─┤ H ├┤0         ├┤ P(0) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├»
#          ┌───┐ ░  └─╥─┘ └───┘│          │└──╥───┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘»
# q8336_0: ┤ X ├─░────╫────────┤1         ├───╫──────────╫──╫──░────╫────────»
#          └───┘ ░    ║        │          │   ║          ║  ║  ░    ║        »
# q8336_1: ──────░────╫────────┤2         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q8337_0: ──────░────╫────────┤3 C-U^256 ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q8337_1: ──────░────╫────────┤4         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q8337_2: ──────░────╫────────┤5         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q8337_3: ──────░────╫────────┤6         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        └──────────┘┌──╨──┐       ║  ║  ░    ║        »
#  c169: 4/═══════════╬════════════════════╡ 0x0 ╞═══════╩══╬═══════╬════════»
#                  ┌──╨──┐                 └─────┘       0  ║    ┌──╨──┐     »
#  c170: 1/════════╡ 0x1 ╞══════════════════════════════════╩════╡ 0x1 ╞═════»
#                  └─────┘                                  0    └─────┘     »
# «         ┌─────────┐┌──────┐┌────────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐┌────────┐»
# «  q8335: ┤0        ├┤ P(0) ├┤ P(π/2) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├┤0       ├»
# «         │         │└──╥───┘└───╥────┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘│        │»
# «q8336_0: ┤1        ├───╫────────╫───────────╫──╫──░────╫────────┤1       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q8336_1: ┤2        ├───╫────────╫───────────╫──╫──░────╫────────┤2       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q8337_0: ┤3 C-U^16 ├───╫────────╫───────────╫──╫──░────╫────────┤3 C-U^4 ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q8337_1: ┤4        ├───╫────────╫───────────╫──╫──░────╫────────┤4       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q8337_2: ┤5        ├───╫────────╫───────────╫──╫──░────╫────────┤5       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q8337_3: ┤6        ├───╫────────╫───────────╫──╫──░────╫────────┤6       ├»
# «         └─────────┘┌──╨──┐  ┌──╨──┐        ║  ║  ░    ║        └────────┘»
# « c169: 4/═══════════╡ 0x0 ╞══╡ 0x1 ╞════════╩══╬═══════╬══════════════════»
# «                    └─────┘  └─────┘        1  ║    ┌──╨──┐               »
# « c170: 1/══════════════════════════════════════╩════╡ 0x1 ╞═══════════════»
# «                                               0    └─────┘               »
# «         ┌──────┐┌────────┐┌────────┐┌─────────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐»
# «  q8335: ┤ P(0) ├┤ P(π/4) ├┤ P(π/2) ├┤ P(3π/4) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├»
# «         └──╥───┘└───╥────┘└───╥────┘└────╥────┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘»
# «q8336_0: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q8336_1: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q8337_0: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q8337_1: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q8337_2: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q8337_3: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «         ┌──╨──┐  ┌──╨──┐   ┌──╨──┐    ┌──╨──┐        ║  ║  ░    ║        »
# « c169: 4/╡ 0x0 ╞══╡ 0x1 ╞═══╡ 0x2 ╞════╡ 0x3 ╞════════╩══╬═══════╬════════»
# «         └─────┘  └─────┘   └─────┘    └─────┘        2  ║    ┌──╨──┐     »
# « c170: 1/════════════════════════════════════════════════╩════╡ 0x1 ╞═════»
# «                                                         0    └─────┘     »
# «         ┌────────┐┌──────┐┌────────┐┌────────┐┌─────────┐┌────────┐»
# «  q8335: ┤0       ├┤ P(0) ├┤ P(π/8) ├┤ P(π/4) ├┤ P(3π/8) ├┤ P(π/2) ├»
# «         │        │└──╥───┘└───╥────┘└───╥────┘└────╥────┘└───╥────┘»
# «q8336_0: ┤1       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q8336_1: ┤2       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q8337_0: ┤3 C-U^2 ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q8337_1: ┤4       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q8337_2: ┤5       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q8337_3: ┤6       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         └────────┘┌──╨──┐  ┌──╨──┐   ┌──╨──┐    ┌──╨──┐   ┌──╨──┐  »
# « c169: 4/══════════╡ 0x0 ╞══╡ 0x1 ╞═══╡ 0x2 ╞════╡ 0x3 ╞═══╡ 0x4 ╞══»
# «                   └─────┘  └─────┘   └─────┘    └─────┘   └─────┘  »
# « c170: 1/═══════════════════════════════════════════════════════════»
# «                                                                    »
# «         ┌─────────┐┌─────────┐┌─────────┐┌───┐┌─┐┌─┐
# «  q8335: ┤ P(5π/8) ├┤ P(3π/4) ├┤ P(7π/8) ├┤ H ├┤M├┤M├
# «         └────╥────┘└────╥────┘└────╥────┘└───┘└╥┘└╥┘
# «q8336_0: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q8336_1: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q8337_0: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q8337_1: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q8337_2: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q8337_3: ─────╫──────────╫──────────╫───────────╫──╫─
# «           ┌──╨──┐    ┌──╨──┐    ┌──╨──┐        ║  ║
# « c169: 4/══╡ 0x5 ╞════╡ 0x6 ╞════╡ 0x7 ╞════════╩══╬═
# «           └─────┘    └─────┘    └─────┘        3  ║
# « c170: 1/══════════════════════════════════════════╩═
# «                                                   0
#
# Controlled Ua Operator 'cUa' =
#          ┌─────────────┐      ┌─────────────────┐
#   q8470: ┤0            ├─■──■─┤0                ├
#          │             │ │  │ │                 │
# q8471_0: ┤1            ├─X──┼─┤1                ├
#          │             │ │  │ │                 │
# q8471_1: ┤2            ├─┼──X─┤2                ├
#          │             │ │  │ │                 │
# q8472_0: ┤3 cMULTamodN ├─X──┼─┤3 inv_cMULTamodN ├
#          │             │    │ │                 │
# q8472_1: ┤4            ├────X─┤4                ├
#          │             │      │                 │
# q8473_0: ┤5            ├──────┤5                ├
#          │             │      │                 │
# q8473_1: ┤6            ├──────┤6                ├
#          └─────────────┘      └─────────────────┘
#
# Controlled Multiplier Operator 'cMULTamodN' =
#                  ┌─────────────┐┌─────────────┐
#   q8494: ────────┤0            ├┤0            ├────────────
#                  │             ││             │
# q8495_0: ────────┤1            ├┤             ├────────────
#                  │             ││             │
# q8495_1: ────────┤             ├┤1            ├────────────
#          ┌──────┐│             ││             │┌──────────┐
# q8496_0: ┤0     ├┤2 ccφADDmodN ├┤2 ccφADDmodN ├┤0         ├
#          │      ││             ││             ││          │
# q8496_1: ┤1 qft ├┤3            ├┤3            ├┤1 inv_qft ├
#          │      ││             ││             ││          │
# q8496_2: ┤2     ├┤4            ├┤4            ├┤2         ├
#          └──────┘│             ││             │└──────────┘
#   q8497: ────────┤5            ├┤5            ├────────────
#                  └─────────────┘└─────────────┘
#
# Controlled Modular Adder Operator 'ccphiamodN' =
#                                                                              »
# q8506_0: ────■────────────────────────────────────────────────────────■──────»
#              │                                                        │      »
# q8506_1: ────■────────────────────────────────────────────────────────■──────»
#          ┌───┴───┐┌───────────┐┌──────────┐     ┌──────┐┌───────┐┌────┴─────┐»
# q8507_0: ┤0      ├┤0          ├┤0         ├─────┤0     ├┤0      ├┤0         ├»
#          │       ││           ││          │     │      ││       ││          │»
# q8507_1: ┤1 φADD ├┤1 inv_φADD ├┤1 inv_qft ├─────┤1 qft ├┤1 φADD ├┤1 φADD_dg ├»
#          │       ││           ││          │     │      ││       ││          │»
# q8507_2: ┤2      ├┤2          ├┤2         ├──■──┤2     ├┤2      ├┤2         ├»
#          └───────┘└───────────┘└──────────┘┌─┴─┐└──────┘└───┬───┘└──────────┘»
#   q8508: ──────────────────────────────────┤ X ├────────────■────────────────»
#                                            └───┘                             »
# «
# «q8506_0: ───────────────────────────────────────■────
# «                                                │
# «q8506_1: ───────────────────────────────────────■────
# «         ┌──────────┐               ┌──────┐┌───┴───┐
# «q8507_0: ┤0         ├───────────────┤0     ├┤0      ├
# «         │          │               │      ││       │
# «q8507_1: ┤1 inv_qft ├───────────────┤1 qft ├┤1 φADD ├
# «         │          │┌───┐     ┌───┐│      ││       │
# «q8507_2: ┤2         ├┤ X ├──■──┤ X ├┤2     ├┤2      ├
# «         └──────────┘└───┘┌─┴─┐└───┘└──────┘└───────┘
# «  q8508: ─────────────────┤ X ├──────────────────────
# «                          └───┘
#
# Phi Adder Operator 'φADD' =
#        ┌──────┐
# q_0: ──┤ P(π) ├─
#      ┌─┴──────┴┐
# q_1: ┤ P(3π/2) ├
#      ├─────────┤
# q_2: ┤ P(3π/4) ├
#      └─────────┘
#
# QFT Circuit =
#                ░                  ░                       ┌───┐ ░
# q8514_0: ──────░──────────────────░──────■──────────■─────┤ H ├─░─
#                ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░
# q8514_1: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░─
#          ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░
# q8514_2: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─
#          └───┘ ░ └─────────┘      ░ └─────────┘                 ░

# %% [markdown]
# ### Combined Benchmark Results

# %%
import sys
sys.path.insert(1, "_common")
import metrics

# metrics.depth_base = 2
# metrics.QV = 64
# apps = [ "Hidden Shift", "Grover's Search", "Quantum Fourier Transform (1)", "Hamiltonian Simulation" ]
# backend_id='qasm_simulator'

metrics.plot_all_app_metrics(backend_id, do_all_plots=False, include_apps=None)
